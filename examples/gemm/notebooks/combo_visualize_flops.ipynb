# %%
import os
import json
import pandas as pd
import altair as alt

# %%
def load_reference_jsons(root_path, filter = ""):
    records = []

    for dirpath, _, filenames in os.walk(root_path):
        if filter in dirpath:
            for file in filenames:
                if file.endswith(".json"):
                    file_path = os.path.join(dirpath, file)
                    try:
                        with open(file_path, 'r') as f:
                            data = json.load(f)
                            records.append(data)
                    except Exception as e:
                        print(f"Error loading {file_path}: {e}")

    return pd.DataFrame(records)

# %%
root_path = "../../../slurm_logs/latest"
df0 = load_reference_jsons(root_path)
df0 = df0.rename(columns={"triton_tflops": "flops"})

root_path = "../../../slurm_logs/reference-latest"
df1 = load_reference_jsons(root_path)

df = pd.concat([df0, df1], ignore_index=True)

# %%
df['algorithm'].unique()
# Out:
# array(['all_scatter', 'one_shot', 'torch_dist_all_gather',
#        'torch_dist_all_reduce'], dtype=object)

# %%
df0
# Out:
#     world_size     m     n      k  debug  validate  trace_tiles  benchmark  \
# 0            4  8192  1152  36864   True      True        False       True
# 1            2  8192  1792  14336   True      True        False       True
# 2            4  8192  8192   7168   True      True        False       True
# 3            4  8192  8192   7680   True      True        False       True
# 4            8  8192   512  14336   True      True        False       True
# 5            8  8192  1024  28672   True      True        False       True
# 6            8  8192   512  12288   True      True        False       True
# 7            8  8192   512  12288   True      True        False       True
# 8            4  8192  4096   3584   True      True        False       True
# 9            8  8192  4096   1536   True      True        False       True
# 10           8  8192  4096   1536   True      True        False       True
# 11           2  8192  2048  12288   True      True        False       True
# 12           2  8192  2048  12288   True      True        False       True
# 13           1  8192  4608  36864   True      True        False       True
# 14           8  8192  8192   3584   True      True        False       True
# 15           2  8192  2048  14336   True      True        False       True
# 16           2  8192  2304  36864   True      True        False       True
# 17           2  8192  3584   7168   True      True        False       True
# 18           1  8192  8192  28672   True      True        False       True
# 19           1  8192  8192  30720   True      True        False       True
# 20           4  8192  1024  12288   True      True        False       True
# 21           4  8192  1024  12288   True      True        False       True
# 22           4  8192  4608   9216   True      True        False       True
# 23           2  8192  4096  28672   True      True        False       True
# 24           8  8192  8192   3840   True      True        False       True
# 25           1  8192  3584  14336   True      True        False       True
# 26           8  8192  4096   1792   True      True        False       True
# 27           8  8192  1024  30720   True      True        False       True
# 28           4  8192  2048  28672   True      True        False       True
# 29           8  8192  4608   4608   True      True        False       True
# 30           2  8192  4608  18432   True      True        False       True
# 31           4  8192  4096   3072   True      True        False       True
# 32           4  8192  4096   3072   True      True        False       True
# 33           4  8192  1024  14336   True      True        False       True
# 34           1  8192  4096  12288   True      True        False       True
# 35           1  8192  4096  12288   True      True        False       True
# 36           1  8192  4096  12288   True      True        False       True
# 37           1  8192  4096  12288   True      True        False       True
# 38           2  8192  8192  14336   True      True        False       True
# 39           8  8192   576  36864   True      True        False       True
# 40           1  8192  4096  14336   True      True        False       True
# 41           8  8192   448  14336   True      True        False       True
# 42           1  8192  8192  28672   True      True        False       True
# 43           2  8192  8192  15360   True      True        False       True
# 44           1  8192  3584  14336   True      True        False       True
# 45           4  8192  2048  30720   True      True        False       True
# 46           4  8192   896  14336   True      True        False       True
# 47           2  8192  4096   7168   True      True        False       True
# 48           1  8192  4096  14336   True      True        False       True
# 49           2  8192  4096   6144   True      True        False       True
# 50           2  8192  4096   6144   True      True        False       True
# 51           4  8192  3584   3584   True      True        False       True
# 52           2  8192  4096  30720   True      True        False       True
# 53           1  8192  8192  30720   True      True        False       True
# 54           8  8192  3584   1792   True      True        False       True
# 55           1  8192  4608  36864   True      True        False       True
#
#    datatype    algorithm  ... streamk_registers  streamk_spills  success  \
# 0      fp32  all_scatter  ...               192               0     True
# 1      fp32  all_scatter  ...               154               0     True
# 2      fp32     one_shot  ...               208               0     True
# 3      fp32     one_shot  ...               208               0     True
# 4      fp32  all_scatter  ...               154               0     True
# 5      fp32  all_scatter  ...               204               0     True
# 6      fp32  all_scatter  ...               154               0     True
# 7      fp32  all_scatter  ...               154               0     True
# 8      fp32     one_shot  ...               256             113     True
# 9      fp32     one_shot  ...               256             112     True
# 10     fp32     one_shot  ...               256             112     True
# 11     fp32  all_scatter  ...               256              92     True
# 12     fp32  all_scatter  ...               256              92     True
# 13     fp32  all_scatter  ...               256              92     True
# 14     fp32     one_shot  ...               208               0     True
# 15     fp32  all_scatter  ...               256              92     True
# 16     fp32  all_scatter  ...               256              92     True
# 17     fp32     one_shot  ...               208               0     True
# 18     fp32  all_scatter  ...               204               0     True
# 19     fp32     one_shot  ...               208               0     True
# 20     fp32  all_scatter  ...               204               0     True
# 21     fp32  all_scatter  ...               204               0     True
# 22     fp32     one_shot  ...               256             113     True
# 23     fp32  all_scatter  ...               154               0     True
# 24     fp32     one_shot  ...               208               0     True
# 25     fp32  all_scatter  ...               204               0     True
# 26     fp32     one_shot  ...               256             112     True
# 27     fp32  all_scatter  ...               204               0     True
# 28     fp32  all_scatter  ...               256              92     True
# 29     fp32     one_shot  ...               256             112     True
# 30     fp32     one_shot  ...               256             109     True
# 31     fp32     one_shot  ...               256             113     True
# 32     fp32     one_shot  ...               256             113     True
# 33     fp32  all_scatter  ...               204               0     True
# 34     fp32     one_shot  ...               154               0     True
# 35     fp32     one_shot  ...               154               0     True
# 36     fp32  all_scatter  ...               154               0     True
# 37     fp32  all_scatter  ...               154               0     True
# 38     fp32     one_shot  ...               208               0     True
# 39     fp32  all_scatter  ...               150               0     True
# 40     fp32     one_shot  ...               154               0     True
# 41     fp32  all_scatter  ...               150               0     True
# 42     fp32     one_shot  ...               208               0     True
# 43     fp32     one_shot  ...               208               0     True
# 44     fp32     one_shot  ...               208               0     True
# 45     fp32  all_scatter  ...               256              92     True
# 46     fp32  all_scatter  ...               192               0     True
# 47     fp32     one_shot  ...               154               0     True
# 48     fp32  all_scatter  ...               154               0     True
# 49     fp32     one_shot  ...               154               0     True
# 50     fp32     one_shot  ...               154               0     True
# 51     fp32     one_shot  ...               208               0     True
# 52     fp32  all_scatter  ...               154               0     True
# 53     fp32  all_scatter  ...               204               0     True
# 54     fp32     one_shot  ...               208               0     True
# 55     fp32     one_shot  ...               256             109     True
#
#     success_partial       flops   triton_ms  streamk_ms streamk_experiments  \
# 0              True  299.620734    9.288873    8.522641                 126
# 1              True  137.118407    6.139319    5.115671                 126
# 2              True  286.699205   13.422746    6.056076                 126
# 3              True  299.792954   13.753387    6.485487                 126
# 4              True  274.477397    3.505107    1.405507                 126
# 5              True  496.228632    7.755076    3.930197                 126
# 6              True  250.128124    3.296845    1.141692                 126
# 7              True  249.212908    3.308953    1.199962                 126
# 8              True   70.762250   13.595846   12.319933                 126
# 9              True   84.513423    9.757429    4.532152                 126
# 10             True   84.579323    9.749826    4.533524                 126
# 11             True   55.775289   14.784930   13.763391                 126
# 12             True   55.851449   14.764768   13.732708                 126
# 13             True   35.421265   78.572541   77.882996                 126
# 14             True  241.673473   15.923513    3.305127                 126
# 15             True   57.980006   16.593180   15.478612                 126
# 16             True   61.183859   45.488121   43.520853                 126
# 17             True  161.693488    5.206231    4.045155                 126
# 18             True  138.415158   27.802524   27.191679                 126
# 19             True  120.909725   34.101216   32.749014                 126
# 20             True  206.064820    4.001817    1.655277                 126
# 21             True  204.844309    4.025661    1.655246                 126
# 22             True   74.245829   37.485457   34.696985                 126
# 23             True  159.786265   24.083989   20.950949                 126
# 24             True  256.131893   16.097834    3.541371                 126
# 25             True  115.840877    7.266982    6.117451                 126
# 26             True   94.627923   10.166900    5.253201                 126
# 27             True  511.024296    8.068439    4.243859                 126
# 28             True  122.004411   31.542226   29.472062                 126
# 29             True  177.465809   15.682676   12.370140                 126
# 30             True   38.381349   72.512792   71.661242                 126
# 31             True   70.465066   11.702731    9.886774                 126
# 32             True   70.382032   11.716538   10.142280                 126
# 33             True  224.349832    4.288270    1.952415                 126
# 34             True   90.980451    9.063856    8.310555                 126
# 35             True   90.747167    9.087157    8.316258                 126
# 36             True  101.180502    8.150125    6.916584                 126
# 37             True  101.026840    8.162521    6.920992                 126
# 38             True  174.287535   22.080126   18.830347                 126
# 39             True  391.895733    7.101733    6.633748                 126
# 40             True   89.089774   10.798912   10.030794                 126
# 41             True  236.053712    3.566195    1.817049                 126
# 42             True  121.097446   31.778463   30.394782                 126
# 43             True  176.516815   23.358503   20.322449                 126
# 44             True  119.648221    7.035738    6.812385                 126
# 45             True  122.687112   33.607186   31.573150                 126
# 46             True  204.302604    4.120425    2.208700                 126
# 47             True  102.883433    9.351094    6.901024                 126
# 48             True  103.381978    9.306000    8.316479                 126
# 49             True  102.981239    8.007611    5.674050                 126
# 50             True  103.631984    7.957328    5.706442                 126
# 51             True  159.595600    5.274667    1.691414                 126
# 52             True  159.899570   25.785989   22.509477                 126
# 53             True  135.753819   30.372395   29.803513                 126
# 54             True  127.914504    6.581064    1.042037                 126
# 55             True   23.956827  116.173100  113.088661                 126
#
#     communication_ms  communication_experiments
# 0           8.623930                        126
# 1           5.903886                        126
# 2          12.959500                        126
# 3          13.262515                        126
# 4           3.191138                        126
# 5           7.391598                        126
# 6           2.839896                        126
# 7           2.980715                        126
# 8          13.197508                        126
# 9           9.308397                        126
# 10          9.319243                        126
# 11         13.813712                        126
# 12         13.781285                        126
# 13         77.768745                        126
# 14         15.347601                        126
# 15         15.531537                        126
# 16         43.523294                        126
# 17          4.957109                        126
# 18         27.488515                        126
# 19         33.777675                        126
# 20          3.706333                        126
# 21          3.700719                        126
# 22         37.004639                        126
# 23         23.495645                        126
# 24         15.418260                        126
# 25          7.026059                        126
# 26          9.728804                        126
# 27          7.667220                        126
# 28         29.732966                        126
# 29         15.276737                        126
# 30         71.771869                        126
# 31         11.236946                        126
# 32         11.315967                        126
# 33          3.988901                        126
# 34          8.829253                        126
# 35          8.848442                        126
# 36          7.910547                        126
# 37          7.923197                        126
# 38         21.743078                        126
# 39          6.744682                        126
# 40         10.539088                        126
# 41          3.218712                        126
# 42         31.441797                        126
# 43         23.076497                        126
# 44          6.797547                        126
# 45         31.822269                        126
# 46          3.835009                        126
# 47          8.938174                        126
# 48          9.079951                        126
# 49          7.606797                        126
# 50          7.549483                        126
# 51          4.898141                        126
# 52         25.021406                        126
# 53         30.039760                        126
# 54          6.139398                        126
# 55        112.814639                        126
#
# [56 rows x 43 columns]

# %%
import pandas as pd
import altair as alt

# Map algorithm codes to readable names
algo_map = {
    "torch_dist_all_gather": "RCCL AllGather",
    "torch_dist_all_reduce": "RCCL AllReduce",
    "all_reduce": "Iris AllReduce",
    "one_shot": "Iris OneShot",
    "all_scatter": "Iris AllScatter"
}
df["algo_label"] = df["algorithm"].map(algo_map)

# Create GEMM shape label
df["shape"] = df.apply(lambda row: f"M{row['M']}N{row['N']}K{row['K']}", axis=1)

# Sort shapes consistently
df = df.sort_values(by=["K", "shape"])
shape_order = df["shape"].drop_duplicates().tolist()

# Loop over each unique world size
for rank in sorted(df["world_size"].unique()):
    filtered = df[df["world_size"] == rank].copy()
    title = f"{rank} GPUs" if rank > 1 else f"{rank} GPU",
    chart = alt.Chart(filtered).mark_bar().encode(
        x=alt.X("shape:N", title="GEMM Shape", sort=shape_order),
        xOffset=alt.XOffset("algo_label:N"),
        y=alt.Y("flops:Q", title="FLOPS (GFLOP/s)", scale=alt.Scale(domainMin=0)),
        color=alt.Color("algo_label:N", title="Algorithm"),
        tooltip=["shape", "algo_label", "flops"]
    ).properties(
        title=title,
        height=300,
        width=60 * len(shape_order)
    ).configure_axisX(
        labelAngle=30
    ).configure_title(
        anchor="middle",
        fontSize=18
    )

    os.makedirs("compare", exist_ok=True)
    os.makedirs("compare/png", exist_ok=True)
    os.makedirs("compare/svg", exist_ok=True)
    os.makedirs("compare/pdf", exist_ok=True)

    fname = f"{rank}_GPUs"
    chart.save(f"compare/svg/{fname}.svg")
    chart.save(f"compare/png/{fname}.png", scale_factor=4)
    chart.save(f"compare/pdf/{fname}.pdf")
    
    chart.display()
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %%
df['algo_label'].unique()
# Out:
# array(['Iris AllScatter', 'Iris OneShot', 'RCCL AllGather',
#        'RCCL AllReduce'], dtype=object)
